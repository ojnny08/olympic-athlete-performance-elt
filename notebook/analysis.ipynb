# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import urllib

def engine():
    connection_string = (
        "DRIVER={ODBC Driver 17 for SQL Server};"
        "SERVER=localhost,1433;"
        "DATABASE=Olympic_Data;"
        "UID=sa;"
        "PWD=Admin@123;"
        "Encrypt=yes;"
        "TrustServerCertificate=yes;"
    )

    params = urllib.parse.quote_plus(connection_string)

    return create_engine(f"mssql+pyodbc:///?odbc_connect={params}", fast_executemany=True)

def read_query(file_path):
    with open(file_path, 'r') as file:
        query = file.read()
    return query

def load_athletes(engine):
    athlete_query = '../queries/athletes_query.sql'
    athletes = read_query(athlete_query)
    return pd.read_sql(athletes, engine)

def load_results(engine):
    results_query = '../queries/results_query.sql'
    results = read_query(results_query)
    return pd.read_sql(results, engine) 

db_engine = engine()

athletes = load_athletes(db_engine)
results = load_results(db_engine)

print("Athletes Data:")
display(athletes.head())  

print("Results Data:")
display(results.head())
# Out:
# /Users/jonathanli/vscode/Olympic_Athletes/env/lib/python3.14/site-packages/pandas/io/sql.py:1648: SAWarning: Unrecognized server version info '17.0.4015.4'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
# Athletes Data:
#                                        Roles   Sex              Used name  \
# 0                  Competed in Olympic Games  Male  Jean-François•Blanchy
# 1                  Competed in Olympic Games  Male         Arnaud•Boetsch
# 2  Competed in Olympic Games • Administrator  Male           Jean•Borotra
# 3                  Competed in Olympic Games  Male        Jacques•Brugnon
# 4                  Competed in Olympic Games  Male           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                               None  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements
# 0            None
# 1  183 cm / 76 kg
# 2  183 cm / 76 kg
# 3  168 cm / 64 kg
# 4            None
# Results Data:
#                   Games                                   Event        Pos  \
# 0  1912 Summer Olympics            Single Sculls, Men (Olympic)  2 h3 r1/4
# 1  1952 Summer Olympics                   Eights, Men (Olympic)  3 h2 r2/5
# 2  1976 Summer Olympics            Coxless Pairs, Men (Olympic)        8.0
# 3  1912 Summer Olympics  Coxed Fours, Outriggers, Men (Olympic)  2 h1 r2/4
# 4  1992 Summer Olympics            Double Sculls, Men (Olympic)       13.0
#
#   Medal                   As  athlete_id  NOC Discipline
# 0  None  Axel Matias Haglund       36767  FIN     Rowing
# 1  None         Yrjö Hakoila       36768  FIN     Rowing
# 2  None          Kari Hanska       36769  FIN     Rowing
# 3  None  Valdemar Henriksson       36770  FIN     Rowing
# 4  None     Esko Hillebrandt       36771  FIN     Rowing

# %% [markdown]
# ## Cleaning Tasks

# %% [markdown]
# - Get rid of bullet points in Used Names
# - Split height/weight
# - Parse out dates from Born & Died column
# - Parse out city, region, and country from Born column
# - Get rid of extra column

# %% [markdown]
# Get rid of dot

# %%
df_athletes = athletes.copy()

count = df_athletes['Used name'].str.contains('•', na=False).sum()
print(count)

df_athletes['Name'] = df_athletes['Used name'].str.replace('•', ' ')
# Out:
# 145500

# %% [markdown]
# Use a small data set to clean before applying to athlete dataset

# %%
small_data = pd.DataFrame(
    ['180 cm', '183 cm / 67 kg', '/ 65 cm', '68 kg /'], columns=['Measurements']
)
small_data['height_cm'] = small_data['Measurements'].str.extract(r'(\d+)\s*cm')
small_data['weight_kg'] = small_data['Measurements'].str.extract(r'(\d+)\s*kg')

# %%
small_data['height_cm'] = pd.to_numeric(small_data['height_cm'])
small_data['weight_kg'] = pd.to_numeric(small_data['weight_kg'])

# %% [markdown]
# Split height & weight into differnet columns

# %%
df_athletes['height_cm'] = df_athletes['Measurements'].str.extract(r'(\d+)\s*cm')
df_athletes['weight_kg'] = df_athletes['Measurements'].str.extract(r'(\d+)\s*kg')

# %%
df_athletes['height_cm'] = pd.to_numeric(df_athletes['height_cm'])
df_athletes['weight_kg'] = pd.to_numeric(df_athletes['weight_kg'])

# %% [markdown]
# Seperating date from location

# %%
date_pattern = r'(\d+ \w+ \d{4})'
df_athletes['born_date'] = df_athletes['Born'].str.extract(date_pattern)
df_athletes['death_date'] = df_athletes['Died'].str.extract(date_pattern)

# %% [markdown]
# Check if all rows follow this pattern
# - keep as NaN if it doesnt follow

# %%
df_athletes[~df_athletes['Born'].str.match(date_pattern, na=False)].head(5)
# Out:
#                                                 Roles   Sex  \
# 12                          Competed in Olympic Games  Male
# 13                          Competed in Olympic Games  Male
# 27  Competed in Olympic Games • Competed in Olympi...  Male
# 28                          Competed in Olympic Games  Male
# 91                          Competed in Olympic Games  Male
#
#              Used name                                Born  \
# 12           J.•Defert                                None
# 13      Étienne•Durand                                None
# 27  Guy, Baron•Lejeune                                None
# 28     Albert•Lippmann                                None
# 91      Lionel•Escombe  1876 in Natal, KwaZulu-Natal (RSA)
#
#                                            Died            NOC  athlete_id  \
# 12                                         None         France          13
# 13                                         None         France          14
# 27                                         None         France          28
# 28                                         None         France          29
# 91  15 October 1914 in Brentford, England (GBR)  Great Britain          92
#
#    Measurements                Name  height_cm  weight_kg born_date  \
# 12         None           J. Defert        NaN        NaN       NaN
# 13         None      Étienne Durand        NaN        NaN       NaN
# 27         None  Guy, Baron Lejeune        NaN        NaN       NaN
# 28         None     Albert Lippmann        NaN        NaN       NaN
# 91         None      Lionel Escombe        NaN        NaN       NaN
#
#          death_date
# 12              NaN
# 13              NaN
# 27              NaN
# 28              NaN
# 91  15 October 1914

# %% [markdown]
# Add a year column because now all rows follow the same date pattern

# %%
df_athletes['Born_year'] = df_athletes['Born'].str.extract(r'(\d{4})')
df_athletes['Death_year'] = df_athletes['Died'].str.extract(r'(\d{4})')

# %% [markdown]
# Change born & death date into timedate objects

# %%
date_columns = ['born_date', 'death_date']
df_athletes[date_columns] = df_athletes[date_columns].apply(pd.to_datetime, errors='coerce')

# %% [markdown]
# Parse out dates from 'born' and 'died' columns

# %%
# working with a small data set first
birth_data = pd.DataFrame([
    '1876 in Natal, '
    'KwaZulu-Natal (RSA)', 
    '12 December 1886 in Bordeaux, Gironde (FRA)', 
    'in Niort, Deux-Sèvres (FRA)'], 
    columns=['Born']
)

location_pattern = r'in (.*)'
birth_data['birth_loc'] = birth_data['Born'].str.extract(location_pattern)

# %%
birth_data
# Out:
#                                           Born                   birth_loc
# 0           1876 in Natal, KwaZulu-Natal (RSA)  Natal, KwaZulu-Natal (RSA)
# 1  12 December 1886 in Bordeaux, Gironde (FRA)     Bordeaux, Gironde (FRA)
# 2                  in Niort, Deux-Sèvres (FRA)    Niort, Deux-Sèvres (FRA)

# %% [markdown]
# Now apply to the athletes dataframe

# %%
location_pattern = r'in (.*)'
df_athletes['Birth_location'] = df_athletes['Born'].str.extract(location_pattern)

# %%
seperation_pattern = r'([\w\s]+), ([\w\s]+) \((\w+)\)'
df_athletes[['City', 'Region', 'Country']] = df_athletes['Birth_location'].str.extract(seperation_pattern)

# %% [markdown]
# Convert columns into its logical datatype

# %%
athlete_cols_int = ['athlete_id', 'Born_year', 'Death_year', 'height_cm', 'weight_kg']
df_athletes[athlete_cols_int] = df_athletes[athlete_cols_int].apply(pd.to_numeric, errors='coerce').astype('Int64')

athlete_cols_str = ['Name', 'Birth_location', 'City', 'Region', 'Country', 'NOC']
df_athletes[athlete_cols_str] = df_athletes[athlete_cols_str].astype("string")

# %%
columns_keep = ['athlete_id', 'Name', 'Sex', 'NOC', 'height_cm', 'weight_kg', 'born_date', 'death_date', 'Born_year', 'Death_year', 'City', 'Region', 'Country']

df_athletes_clean = df_athletes[columns_keep]

# %%
df_athletes_clean.head(5)
# Out:
#    athlete_id                   Name   Sex     NOC  height_cm  weight_kg  \
# 0           1  Jean-François Blanchy  Male  France       <NA>       <NA>
# 1           2         Arnaud Boetsch  Male  France        183         76
# 2           3           Jean Borotra  Male  France        183         76
# 3           4        Jacques Brugnon  Male  France        168         64
# 4           5           Albert Canet  Male  France       <NA>       <NA>
#
#    born_date death_date  Born_year  Death_year         City    Region Country
# 0 1886-12-12 1960-10-02       1886        1960     Bordeaux   Gironde     FRA
# 1 1969-04-01        NaT       1969        <NA>       Meulan  Yvelines     FRA
# 2 1898-08-13 1994-07-17       1898        1994         <NA>      <NA>    <NA>
# 3 1895-05-11 1978-03-20       1895        1978  Paris VIIIe     Paris     FRA
# 4 1878-04-17 1930-07-25       1878        1930   Wandsworth   England     GBR

# %%
df_athletes_clean.to_csv('../data/processed/athletes.csv', index=False)

# %% [markdown]
# ### Clean Results csv

# %% [markdown]
# - Remove = and DNS into NA
# - Add a seasons and year column
# - Parse Male events from Female events

# %%
df_results = results.copy()

# %%
# Replcae the = with ' '
df_results['Pos_clean'] = df_results['Pos'].str.replace('=', ' ')

# Convert into a numeric object to turn all DNF and DNS into NAN
df_results['Pos_clean'] = pd.to_numeric(df_results['Pos_clean'], errors='coerce')

# %% [markdown]
# Find games that dont match the pattern
# - One game spans 2 years
# - Some games dont have a season

# %%
games_pattern = r'(\d{4} \w+ \w+)'
df_results[~df_results['Games'].str.contains(games_pattern, na=False)]
# Out:
# /var/folders/zd/qbk_l4lx5_v5pwtr7z4cryt40000gn/T/ipykernel_7221/2399546709.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_results[~df_results['Games'].str.contains(games_pattern, na=False)]
#                               Games                  Event Pos Medal  \
# 40863  1888-89 Zappas Olympic Games  Rope Climbing, Men ()   1  None
#
#                     As  athlete_id  NOC                        Discipline  \
# 40863  Sotirios Versis       55911  GRE  Artistic Gymnastics (Gymnastics)
#
#        Pos_clean
# 40863        1.0

# %%
# Use the start year of the event
year = r'(\d{4})'
df_results['Games_Year'] = df_results['Games'].str.extract(year)

# Extract the season then set NA to the games without a season
season_pattern = r'\d{4} (\w+)'
df_results['Season'] = df_results['Games'].str.extract(season_pattern)

season_list = ['Winter', 'Summer', 'Fall', 'Spring']
df_results.loc[~df_results['Season'].isin(season_list), 'Season'] = pd.NA

# %% [markdown]
# Gender

# %%
# Filter out males and females
genders = r'\b(Men|Women)\b'
df_results['Gender'] = df_results['Event'].str.extract(genders)

# %%
discipline_pattern = r'\s\(.*\)'
df_results['Discipline_clean'] = df_results['Discipline'].str.replace(discipline_pattern, ' ', regex=True)

# %%
df_results['Name'] = df_results['As'].str.replace('-', ' ')

# %%
event_pattern = r'(.*), '
df_results['Event_clean'] = df_results['Event'].str.extract(event_pattern)

# %% [markdown]
# Convert medals into integers

# %%
# remove whitespace and change into lowercase to normalize
df_results['Medal'] = df_results['Medal'].str.strip().str.lower()

medal_map = {
    'gold': 3,
    'silver': 2,
    'bronze': 1,
}

df_results['Points'] = df_results['Medal'].map(medal_map).fillna(0)

# %% [markdown]
# Medalist or non-medlaist

# %%
df_results['Preformance_Result'] = df_results['Points'].apply(lambda x: 'Medalist' if x > 0 else 'non-Medalist')

# %% [markdown]
# Remove redundant columns & assign appropriate datatype

# %%
results_columns_keep = ['athlete_id', 'Name', 'Gender', 'Discipline_clean', 'Event_clean', 'Medal', 'Points', 'Preformance_Result', 'Pos_clean', 'Games_Year', 'Season']
df_results = df_results[results_columns_keep]

df_results.tail(5)
# Out:
#         athlete_id            Name Gender Discipline_clean  \
# 308403       36762      Veli Autio    Men           Rowing
# 308404       36763  Helge Forsberg    Men           Rowing
# 308405       36764  Osrik Forsberg    Men           Rowing
# 308406       36765   Oskar Forsman    Men           Rowing
# 308407       36766   Kurt Grönholm    Men           Rowing
#
#                     Event_clean Medal  Points Preformance_Result  Pos_clean  \
# 308403              Coxed Fours  None     0.0       non-Medalist        NaN
# 308404              Coxed Fours  None     0.0       non-Medalist        NaN
# 308405              Coxed Fours  None     0.0       non-Medalist        NaN
# 308406  Coxed Fours, Outriggers  None     0.0       non-Medalist        NaN
# 308407              Coxed Fours  None     0.0       non-Medalist        5.0
#
#        Games_Year  Season
# 308403       1948  Summer
# 308404       1948  Summer
# 308405       1948  Summer
# 308406       1912  Summer
# 308407       1952  Summer

# %%
results_cols_str = ['Name', 'Gender', 'Discipline_clean', 'Event_clean', 'Medal', 'Season', 'Preformance_Result']
results_cols_int = ['athlete_id', 'Points', 'Pos_clean', 'Games_Year']

df_results_clean = df_results[results_cols_str + results_cols_int].copy()

df_results_clean[results_cols_str] = df_results_clean[results_cols_str].astype('string')
df_results_clean[results_cols_int] = df_results_clean[results_cols_int].apply(pd.to_numeric, errors='coerce').astype('Int64')

df_results_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Name                308408 non-null  string
#  1   Gender              284954 non-null  string
#  2   Discipline_clean    308407 non-null  string
#  3   Event_clean         306583 non-null  string
#  4   Medal               44139 non-null   string
#  5   Season              305807 non-null  string
#  6   Preformance_Result  308408 non-null  string
#  7   athlete_id          308408 non-null  Int64
#  8   Points              308408 non-null  Int64
#  9   Pos_clean           234554 non-null  Int64
#  10  Games_Year          308408 non-null  Int64
# dtypes: Int64(4), string(7)
# memory usage: 27.1 MB

# %%
df_results_clean.to_csv('../data/processed/results.csv')

# %% [markdown]
# Group into age groups
# - Merge df_athletes and df_results together

# %%
columns = ['athlete_id','height_cm', 'weight_kg', 'Born_year', 'Death_year', 'Country']

df_merge = df_results_clean.merge(df_athletes_clean[columns], on='athlete_id', how='left')

# %% [markdown]
# Find the age groups of athletes

# %%
df_merge['Age'] = df_merge['Games_Year'] - df_merge['Born_year']
df_merge['Age'] = pd.to_numeric(df_merge['Age'], errors='coerce')

# Youngest age 11 and oldest 73
df_merge['Age'].min()
df_merge['Age'].max()

# Any Na
df_merge[df_merge['Age'].isna()]

# Group them accordingly
age_bin = [13, 20, 30, 40, 50, 60, 70, 80]

age_groups = np.array(['11-12', '13-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79'])

index = np.digitize(df_merge['Age'].fillna(-1), age_bin)

df_merge['Age_group'] = age_groups[index]

# For the NA ages change the gorup to unknown
df_merge.loc[df_merge['Age'].isna(), 'Age_group'] = 'Unknown'

# %%
df_merge[df_merge['Age_group'] == 'Unknown'].head(5)
# Out:
#                Name Gender Discipline_clean    Event_clean Medal  Season  \
# 110           Angot    Men           Rowing    Coxed Fours  <NA>  Summer
# 130  Raymond Benoit    Men           Rowing  Single Sculls  <NA>  Summer
# 133    René Beslaud   <NA>           Rowing  Coxless Fours  <NA>  Summer
# 134    René Beslaud    Men           Rowing    Coxed Fours  <NA>  Summer
# 135       J. Bétout    Men           Rowing         Eights  <NA>  Summer
#
#     Preformance_Result  athlete_id  Points  Pos_clean  Games_Year  height_cm  \
# 110       non-Medalist       36845       0       <NA>        1900       <NA>
# 130       non-Medalist       36863       0       <NA>        1900       <NA>
# 133       non-Medalist       36867       0          1        1900       <NA>
# 134       non-Medalist       36867       0       <NA>        1900       <NA>
# 135       non-Medalist       36868       0       <NA>        1924       <NA>
#
#      weight_kg  Born_year  Death_year Country   Age Age_group
# 110       <NA>       <NA>        <NA>    <NA>  <NA>   Unknown
# 130       <NA>       <NA>        <NA>    <NA>  <NA>   Unknown
# 133       <NA>       <NA>        <NA>    <NA>  <NA>   Unknown
# 134       <NA>       <NA>        <NA>    <NA>  <NA>   Unknown
# 135       <NA>       <NA>        <NA>    <NA>  <NA>   Unknown

# %% [markdown]
# Calculate BMI

# %%
df_merge['BMI'] = (df_merge['weight_kg'] / (df_merge['height_cm'] / 100)**2)

# %% [markdown]
# Find the points for each age group for each Olympic year
# - Store it in a seperate df because if we have 1000 athletes in a certain age group for a year it will repeate it 1000 times

# %%
# Store in seperate df
df_year_total_points = df_merge.groupby(['Games_Year', 'Age_group'])['Points'].sum().reset_index()

df_year_total_points.to_csv('../data/processed/year_total_points.csv')

# %% [markdown]
# Find podium appearances percentage of the age groups and their disicipline
# - Because the age group 20-29 has more participants they will always have more points so here calculate podium appearance percentage

# %%
# Count by medal since points has values of 0
df_podium_appearance_country_age = df_merge.groupby(['Games_Year', 'Country', 'Age_group']).agg({
    'athlete_id' : 'count',
    'Medal' : 'count'
}).reset_index()

df_podium_appearance_country_age['Appearance_%'] = ((df_podium_appearance_country_age['Medal'] / df_podium_appearance_country_age['athlete_id']) * 100).round(2)

df_podium_appearance_country_age
df_podium_appearance_country_age.to_csv('../data/processed/podium_appearances_age.csv')

# %% [markdown]
# The mean & std of medalist vs non-medalist in their discipline

# %%
df_physical_preformance = df_merge.groupby(['Games_Year', 'Discipline_clean', 'Preformance_Result']).agg({
    'height_cm': ['mean', 'std'],
    'weight_kg': ['mean', 'std'],
}).reset_index()

df_physical_preformance.to_csv('../data/processed/physical_preformance.csv')
df_physical_preformance.tail(50)
# Out:
#      Games_Year            Discipline_clean Preformance_Result   height_cm  \
#                                                                       mean
# 2310       2020                   Swimming            Medalist  183.342857
# 2311       2020                   Swimming        non-Medalist   181.47323
# 2312       2020                Table Tennis           Medalist       169.0
# 2313       2020                Table Tennis       non-Medalist  173.232258
# 2314       2020                   Taekwondo           Medalist  179.555556
# 2315       2020                   Taekwondo       non-Medalist  184.457143
# 2316       2020                      Tennis           Medalist  184.636364
# 2317       2020                      Tennis       non-Medalist  180.743421
# 2318       2020               Trampolining            Medalist  169.666667
# 2319       2020               Trampolining        non-Medalist  168.846154
# 2320       2020                   Triathlon           Medalist  175.888889
# 2321       2020                   Triathlon       non-Medalist  172.693333
# 2322       2020                 Volleyball            Medalist  189.862745
# 2323       2020                 Volleyball        non-Medalist  190.058442
# 2324       2020                 Water Polo            Medalist  186.514286
# 2325       2020                 Water Polo        non-Medalist  186.950617
# 2326       2020               Weightlifting           Medalist  167.863636
# 2327       2020               Weightlifting       non-Medalist  168.246575
# 2328       2020                   Wrestling           Medalist  175.771429
# 2329       2020                   Wrestling       non-Medalist  172.358025
# 2330       2022              Alpine Skiing            Medalist  175.638889
# 2331       2022              Alpine Skiing        non-Medalist  175.764012
# 2332       2022                    Biathlon           Medalist  174.711111
# 2333       2022                    Biathlon       non-Medalist  173.878935
# 2334       2022                  Bobsleigh            Medalist  181.529412
# 2335       2022                  Bobsleigh        non-Medalist  182.181818
# 2336       2022       Cross Country Skiing            Medalist  175.444444
# 2337       2022       Cross Country Skiing        non-Medalist  173.143216
# 2338       2022                     Curling           Medalist  170.761905
# 2339       2022                     Curling       non-Medalist  171.690476
# 2340       2022             Figure Skating            Medalist  168.962963
# 2341       2022             Figure Skating        non-Medalist       169.5
# 2342       2022           Freestyle Skiing            Medalist  173.225806
# 2343       2022           Freestyle Skiing        non-Medalist  172.235714
# 2344       2022                 Ice Hockey            Medalist  176.860465
# 2345       2022                 Ice Hockey        non-Medalist  177.431925
# 2346       2022                        Luge           Medalist       180.0
# 2347       2022                        Luge       non-Medalist  179.657143
# 2348       2022            Nordic Combined            Medalist       179.2
# 2349       2022            Nordic Combined        non-Medalist  178.577465
# 2350       2022  Short Track Speed Skating            Medalist    171.5625
# 2351       2022  Short Track Speed Skating        non-Medalist  171.335526
# 2352       2022                   Skeleton            Medalist      174.25
# 2353       2022                   Skeleton        non-Medalist  174.277778
# 2354       2022                Ski Jumping            Medalist  171.041667
# 2355       2022                Ski Jumping        non-Medalist  173.192661
# 2356       2022               Snowboarding            Medalist  173.793103
# 2357       2022               Snowboarding        non-Medalist  171.528302
# 2358       2022              Speed Skating            Medalist  174.765957
# 2359       2022              Speed Skating        non-Medalist  174.847222
#
#                  weight_kg
#             std       mean        std
# 2310   7.089847  72.057692   11.13625
# 2311   9.459835  71.812721  11.101315
# 2312  12.627131  61.789474  12.222834
# 2313   9.842143  66.782895  11.388921
# 2314  10.223883  63.111111  12.898105
# 2315  10.345055  73.878788  13.327034
# 2316  10.346717  72.888889  11.698765
# 2317   9.540084  72.666667  10.811862
# 2318   2.081666       62.0   6.244998
# 2319   8.830309  62.222222   7.529571
# 2320   5.754226       62.0   6.377042
# 2321   7.407033  59.057143   7.560166
# 2322    9.23476  81.931818  12.507482
# 2323  10.247421  80.479592  11.132964
# 2324  10.028572  84.405797  15.531106
# 2325   9.518274  88.506849  14.531693
# 2326  12.969912  88.863636  36.563442
# 2327  11.411228  82.114943  25.425873
# 2328  11.048252  83.111111  25.541873
# 2329  10.466982  76.592105  21.201998
# 2330   7.559867  74.866667  11.545213
# 2331   8.350162  74.981073  11.294936
# 2332   9.345933  67.181818   9.063786
# 2333    8.51953  66.705882   9.416458
# 2334   8.675523  93.705882  10.699093
# 2335   7.093052  92.119048  12.595089
# 2336   8.904941  67.371429  10.569339
# 2337   8.991297  65.967568   9.795139
# 2338   12.67243      67.35  12.815595
# 2339  11.310449  69.428571  13.722643
# 2340  11.953376      64.35  15.142394
# 2341  11.098307  61.164179   14.57852
# 2342     8.6012  68.344828  11.598263
# 2343   9.113679  66.266667  11.078584
# 2344  10.117152  78.714286  12.107911
# 2345   9.847963   75.75641  13.662462
# 2346   7.516648  81.571429   8.749694
# 2347   7.101512  82.485714  10.179181
# 2348   5.659379  63.909091    5.75247
# 2349   6.232775  65.560606   5.421123
# 2350   7.196058  65.613636   8.947433
# 2351     8.0297  64.797101   9.550602
# 2352   9.105859       72.5   7.593857
# 2353   8.013265  74.611111  10.809249
# 2354   6.987437  59.363636   4.041987
# 2355    8.33053  58.347368   6.337609
# 2356   9.802985  68.178571  12.180901
# 2357   8.921466  67.137255  11.699673
# 2358   9.439079  67.777778  10.051886
# 2359   8.308572  68.295181    9.96799

# %% [markdown]
# ## Plotting

# %% [markdown]
# Medal vs Country

# %%
import matplotlib.pyplot as plt

df_2022 = df_podium_appearance_country_age.query('Games_Year == 2022')

top_countires = df_2022.groupby('Country')['Medal'].sum().nlargest(10).index

df_top = df_2022[df_2022['Country'].isin(top_countires)]

df_top.pivot(index='Country', columns='Age_group', values='Medal').plot(kind='bar', figsize=(15,7))

plt.title('Top 10 Countires: Medals won by Age Group and Country (2022)')
plt.ylabel('Medels')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Body weight and height in their games category
